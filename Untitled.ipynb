# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df = pd.read_csv("Retail_Sales_Data/Official_Merged_SF.csv").dropna()

# %%
df
# Out:
#          sale_date  store  temperature  fuel_price  markdown1  markdown2  \
# 62      2011-11-11     16        29.56       3.505    5042.40    2193.04
# 63      2011-11-18     16        31.73       3.479    2089.46     154.21
# 64      2011-11-25     16        31.39       3.424      90.28     126.47
# 66      2011-12-23     16        20.79       3.173     485.00       0.18
# 67      2011-12-30     16        23.91       3.119     921.67   11778.68
# ...            ...    ...          ...         ...        ...        ...
# 565957  2012-06-15     16        65.36       3.723    7027.33     141.80
# 565958  2012-06-22     16        70.41       3.735    1291.33     201.00
# 565960  2012-07-13     16        70.29       3.613    2375.53      17.90
# 565961  2012-07-20     16        68.43       3.585    1115.42     105.35
# 565964  2012-08-24     16        61.44       3.558    1556.47      16.00
#
#         markdown3  markdown4  markdown5  unemployment  isholiday  dept  \
# ...

# %%
# assigning the data to X and y
X = df[["markdown1", "markdown2", "markdown3", "markdown4", "markdown5"]]
y = df["weekly_sales"].values.reshape(-1,1)
print(X.shape, y.shape)
# Out:
# (149916, 5) (149916, 1)

# %%
# assigning the data to X and y
X = df["isholiday"].values.reshape(-1,1)
y = df["markdown5"].values.reshape(-1,1)
print(X.shape, y.shape)
# Out:
# (149916, 1) (149916, 1)

# %%
# Use train_test_split to create training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# #  Create the model using LinearRegression
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.012146902570273066
# Testing Score: 0.012005386357478942
